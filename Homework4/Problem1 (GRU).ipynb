# %%
import string
import random
import torch
import torch.nn as nn
import matplotlib.pyplot as plt

# %% [markdown]
# #### Prepare for Dataset

# %%
all_chars       = string.printable
n_chars         = len(all_chars)
file            = open('./shakespeare.txt').read()
file_len        = len(file)

print('Length of file: {}'.format(file_len))
print('All possible characters: {}'.format(all_chars))
print('Number of all possible characters: {}'.format(n_chars))
# Out:
# Length of file: 1115394
# All possible characters: 0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
#
# Number of all possible characters: 100

# %%
# Get a random sequence of the Shakespeare dataset.
def get_random_seq():
    seq_len     = 128  # The length of an input sequence.
    start_index = random.randint(0, file_len - seq_len)
    end_index   = start_index + seq_len + 1
    return file[start_index:end_index]

# Convert the sequence to one-hot tensor.
def seq_to_onehot(seq):
    tensor = torch.zeros(len(seq), 1, n_chars) 
    # Shape of the tensor:
    #     (sequence length, batch size, classes)
    # Here we use batch size = 1 and classes = number of unique characters.
    for t, char in enumerate(seq):
        index = all_chars.index(char)
        tensor[t][0][index] = 1
    return tensor

# Convert the sequence to index tensor.
def seq_to_index(seq):
    tensor = torch.zeros(len(seq), 1)
    # Shape of the tensor: 
    #     (sequence length, batch size).
    # Here we use batch size = 1.
    for t, char in enumerate(seq):
        tensor[t] = all_chars.index(char)
    return tensor

# Sample a mini-batch including input tensor and target tensor.
def get_input_and_target():
    seq    = get_random_seq()
    input  = seq_to_onehot(seq[:-1])      # Input is represented in one-hot.
    target = seq_to_index(seq[1:]).long() # Target is represented in index.
    return input, target

# %% [markdown]
# #### Choose a Device

# %%
# If there are GPUs, choose the first one for computing. Otherwise use CPU.
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)  
# If 'cuda:0' is printed, it means GPU is available.
# Out:
# cpu

# %% [markdown]
# #### Network Definition

# %%
class Net(nn.Module):
    def __init__(self):
        # Initialization.
        super(Net, self).__init__()
        self.input_size  = n_chars   # Input size: Number of unique chars.
        self.hidden_size = 100       # Hidden size: 100.
        self.output_size = n_chars   # Output size: Number of unique chars.
        
        self.encoder = nn.GRUCell(self.input_size, self.hidden_size)
        self.decoder = nn.Linear(self.hidden_size, self.output_size)
    
    def forward(self, input, hidden):
        """ Forward function.
              input:  One-hot input. It refers to the x_t in homework write-up.
              hidden: Previous hidden state. It refers to the h_{t-1}.
            Returns (output, hidden) where output refers to y_t and 
                     hidden refers to h_t.
        """
        # Forward function.
        hidden = self.encoder(input, hidden) ###### To be filled ######
        output = self.decoder(hidden) ###### To be filled ######

        return output, hidden

    def init_hidden(self):
        # Initial hidden state.
        # 1 means batch size = 1.
        return torch.zeros(1, self.hidden_size).to(device) 
    
net = Net()     # Create the network instance.
net.to(device)  # Move the network parameters to the specified device.
# Out:
# Net(
#   (encoder): GRUCell(100, 100)
#   (decoder): Linear(in_features=100, out_features=100, bias=True)
# )

# %% [markdown]
# #### Training Step and Evaluation Step

# %%
# Training step function.
def train_step(net, opt, input, target):
    """ Training step.
        net:    The network instance.
        opt:    The optimizer instance.
        input:  Input tensor.  Shape: [seq_len, 1, n_chars].
        target: Target tensor. Shape: [seq_len, 1].
    """
    seq_len = input.shape[0]    # Get the sequence length of current input.
    hidden = net.init_hidden()  # Initial hidden state.
    net.zero_grad()             # Clear the gradient.
    loss = 0                    # Initial loss.

    for t in range(seq_len):    # For each one in the input sequence.
        output, hidden = net(input[t], hidden)
        loss += loss_func(output, target[t])

    loss.backward()             # Backward. 
    opt.step()                  # Update the weights.

    return loss / seq_len       # Return the average loss w.r.t sequence length.

# %%
# Evaluation step function.
def eval_step(net, init_seq='W', predicted_len=100):
    # Initialize the hidden state, input and the predicted sequence.
    hidden        = net.init_hidden()
    init_input    = seq_to_onehot(init_seq).to(device)
    predicted_seq = init_seq

    # Use initial string to "build up" hidden state.
    for t in range(len(init_seq) - 1):
        output, hidden = net(init_input[t], hidden)
        
    # Set current input as the last character of the initial string.
    input = init_input[-1]
    
    # Predict more characters after the initial string.
    for t in range(predicted_len):
        # Get the current output and hidden state.
        output, hidden = net(input, hidden)
        
        # Sample from the output as a multinomial distribution.
        predicted_index = torch.multinomial(output.view(-1).exp(), 1)[0]
        
        # Add predicted character to the sequence and use it as next input.
        predicted_char  = all_chars[predicted_index]
        predicted_seq  += predicted_char
        
        # Use the predicted character to generate the input of next round.
        input = seq_to_onehot(predicted_char)[0].to(device)

    return predicted_seq

# %% [markdown]
# #### Training Procedure

# %%
# Number of iterations.
iters       = 15000  # Number of training iterations.
print_iters = 100    # Number of iterations for each log printing.

# The loss variables.
all_losses = []
loss_sum   = 0

# Initialize the optimizer and the loss function.
opt       = torch.optim.Adam(net.parameters(), lr=0.005)
loss_func = nn.CrossEntropyLoss()

# Training procedure.
for i in range(iters):
    input, target = get_input_and_target()            # Fetch input and target.
    input, target = input.to(device), target.to(device) # Move to GPU memory.
    loss      = train_step(net, opt, input, target)   # Calculate the loss.
    loss_sum += loss                                  # Accumulate the loss.

    # Print the log.
    if i % print_iters == print_iters - 1:
        print('iter:{}/{} loss:{}'.format(i, iters, loss_sum / print_iters))
        print('generated sequence: {}\n'.format(eval_step(net)))
              
        # Track the loss.
        all_losses.append(loss_sum / print_iters)
        loss_sum = 0
# Out:
# iter:99/20000 loss:3.1595852375030518
# generated sequence: W}a, mePc whae lere y >olg of
# cf lasiRve:Nur me core, h fonof.
# Ds sy cer i moss imi soiatir;
# Rup:
# IN'
#
# iter:199/20000 loss:2.5630786418914795
# generated sequence: Wea t am srad wo ciiwise noud, sm sa stK
# I Io, math,
# WO,
# Whave! sthif,
# WIm cote, Soo ou tho aople wat
#
# iter:299/20000 loss:2.405449151992798
# generated sequence: Whd un, youle;
#
# urlirr chas heereicl io mens
# Gim fir,
# Cacrove mel,
# Whaot,. o fat hagisurs:
# Hnoumes hu
#
# iter:399/20000 loss:2.3453826904296875
# generated sequence: Wachat piyis.
# T ans mys,
# to-r to mithize,
# Aly mall matly thu thacken bu.
# AFret,
# Ant:
# Ahy o donds.
# And
#
# iter:499/20000 loss:2.300445079803467
# generated sequence: WI someno rimigh in ave rother' non,
# He hawh! 'r
# Bewes pour brsime, be the hise's,
#
# SLANUTENHFEKOLE:
#
# iter:599/20000 loss:2.21688175201416
# generated sequence: Walt seand unscennt auke lrrotaduss mister, not serarver ofurgust ap weak!
# Ceay sheten act ben, efotn
#
# iter:699/20000 loss:2.174764633178711
# generated sequence: Whall have
# blive dothous limstriPls brend.
# By you, buthy.
# Foreton,
# So spacen porubuss thein ingea nor
#
# iter:799/20000 loss:2.1533896923065186
# generated sequence: Wermime ef heof I stbeld goy, sited than, sam condfalt?
# Bey thiths's fore I charcewy therding
# As wa t
#
# iter:899/20000 loss:2.11203932762146
# generated sequence: WI his I be quatisall ous gimO, cods caloy besme,
# For uigh.
#
# ALYORULEO:
# OSY Caysen, dust:
# Serest you
#
# iter:999/20000 loss:2.104313611984253
# generated sequence: W!
# And ableathis sser'sing, as no, nobleitce in as a lockerd.
#
# Firo soizo you be as and coma not to t
#
# iter:1099/20000 loss:2.028663396835327
# generated sequence: Whald,
# What suciny dir dithind of have hfed herswso diding has' liwat sfor
# Ie to bether', shese firns
#
# iter:1199/20000 loss:2.015038251876831
# generated sequence: We that fathall, hou?
#
# PoRINES:
# The way Mweant:
# I he batce, theines mow.
# No prow!
# crouch, fol: at You
#
# iter:1299/20000 loss:1.9879319667816162
# generated sequence: Went mP -hin pars, I fail'st hos fout inchias:
# shed
# Bewille or him I as in the hifr I canded'll sucit
#
# iter:1399/20000 loss:1.981225609779358
# generated sequence: Which hake west you lichy nourdven shex grown steent, otoun thin in hes pleectast;
# I that een couss R
#
# iter:1499/20000 loss:1.964465618133545
# generated sequence: W; fornow, cout ray,
# 'Ta gord, weepo per love
# Crrenou and my leatthervir, of lustingso llupet abti-be
#
# iter:1599/20000 loss:1.9518016576766968
# generated sequence: What ned leng tham sols
# Gik. Why whe the me, wake to wain him,
# And weathise poor this monds:
# And the
#
# iter:1699/20000 loss:1.9149644374847412
# generated sequence: Waince wefancony.
#
# SOCKIOG ILEMO:
# Mase in eadme For promay and were I'llins,
# Gloz?
# That chustac vare
#
# iter:1799/20000 loss:1.9171528816223145
# generated sequence: Way, tolkspengrite may.
# Sarchey. Goend.
#
# FRA be:
# I he gravenfes veisars of drevire well worlobubter N
#
# iter:1899/20000 loss:1.9214428663253784
# generated sequence: With, Camad of
# by goom the quean usters;
# Comms, and fer; mare hir,
# Andy oye comoone,
# Your be the spel
#
# iter:1999/20000 loss:1.9091041088104248
# generated sequence: Were Varnacolicee!
# Faut till me of methind stoby tale tow
# My doll rome, Sirst and not, my upand at ow
#
# iter:2099/20000 loss:1.8477951288223267
# generated sequence: WUCHISTA:
# ABy ablous potuin: such yot that my godder, low! Buttign phiss Happaind.
# Whidan and shall g
#
# iter:2199/20000 loss:1.8192908763885498
# generated sequence: WA:
# O, theme that erstan'd thee, it har's back. What nattragy. out and do, then.
#
# MERUMEO:
# Yet to gue
#
# iter:2299/20000 loss:1.824426293373108
# generated sequence: Which mee and feartay chif rechiled
# With my, do you sights:
# Had shelf swe mory to blead,
# Thee could's
#
# iter:2399/20000 loss:1.8623051643371582
# generated sequence: Whap then what yot me med, none ispeques
#
# MENGAHEL:
# Lord, not day, a struidued: denbleast.
#
# BUSTIONS:
#
# iter:2499/20000 loss:1.831800937652588
# generated sequence: Wars not my thy stremb
# bard a day this so steem,
# The for though not light is, in't right thures dure
#
# iter:2599/20000 loss:1.8395216464996338
# generated sequence: Will dust and po monry ling giather bickingrish
# That you be his beoket my bestings'd;
# If you rose I h
#
# iter:2699/20000 loss:1.8305171728134155
# generated sequence: WARUT:
# That us deatum as 'dence,
# Ancedse coames to thie o.
# Come to sirve lep and than red thears?
#
# DU
#
# iter:2799/20000 loss:1.8118531703948975
# generated sequence: Whes thou have wfay pratur,
# Thind show the wath a thou wise!
# Tome, st Clave of I proarm appitce:
# Inou
#
# iter:2899/20000 loss:1.7987534999847412
# generated sequence: Wild ffoet's thay..
# No, so lorfich um.
#
# BRUS BY:
# In poing a gue sir nivy hors price
# And bllood like i
#
# iter:2999/20000 loss:1.8050285577774048
# generated sequence: Werh's be.
# Enge to ceakpoing steen your father:
# For pace of mickn would i inHerthy and gide.
#
# LARMARI
#
# iter:3099/20000 loss:1.7795332670211792
# generated sequence: Willo?
#
# RICHAR MS:
# She fromment you uncies.
#
# TOY MARTIO:
# You, she liveen deget.
#
# RUCHIO:
# Ersimorgheer
#
# iter:3199/20000 loss:1.7618496417999268
# generated sequence: WIBABRDUKET:
# Hear- onough lecy. Maree; mer'd.
#
# KING EDWARD II:
# Thy asse to thied I smilk cosd of Rich
#
# iter:3299/20000 loss:1.7866767644882202
# generated sequence: WING RINCHARD:
# Where 'ters if the do but then mowerwhowhte drece?
#
# SICINING S:
# Bry's redse for trean
#
# iter:3399/20000 loss:1.7582148313522339
# generated sequence: Wordigno,
# Whalk the kond, his riccome upon 'siss yet undrear
# Fike I doon a girce.
#
# JULIET:
# Shall serv
#
# iter:3499/20000 loss:1.749690055847168
# generated sequence: Will, it she promileal, heneesblecy go fobforgo,
# And he? 'Twill?
#
# CELARD:
# My lead for the and swe,
# Fr
#
# iter:3599/20000 loss:1.7762548923492432
# generated sequence: Well me,
# Steed strope, a God or Beish and less,
# 3urdit of the eremare come, my keep-day; to havy I'll
#
# iter:3699/20000 loss:1.758249044418335
# generated sequence: Well,-'thiram not soesholds,
# But thou dreadry our peed your by they: as
# Withispit, deary, be armenter
#
# iter:3799/20000 loss:1.7438288927078247
# generated sequence: Wise Merell'a?
#
# Squis you knighcemant my least,
# And; I say.
#
# RICHARD:
# Who, Tole! Whenoty now mure;
# In
#
# iter:3899/20000 loss:1.7442747354507446
# generated sequence: Whintied, this you shove him.
# Good hall undoth hind come I werl, are store:
# Heak I'll sorloother, pra
#
# iter:3999/20000 loss:1.7048918008804321
# generated sequence: Wbow'd die the ray, loven uslenier,
# A love should furding wit, at wo'th woald Sir belcom chist,
# Not t
#
# iter:4099/20000 loss:1.735499382019043
# generated sequence: Will sheonge:
# I dalub which cisures! Those shephers quers usll.
#
# ANIO:
# Ay! that hay not so the let; s
#
# iter:4199/20000 loss:1.7418878078460693
# generated sequence: WADY MOLANUS:
# Good more do the in this loss
# I of gear hear,
# Thou haid of thee shoththed withoul dome,
#
# iter:4299/20000 loss:1.6855971813201904
# generated sequence: WARD IIS:
# Nath, and stalled my lare in ere, to prosal, Edward,
# And hearthand, toss known and do kingm
#
# iter:4399/20000 loss:1.7242664098739624
# generated sequence: WARThat I purce, fels, a dir-am
# You like of Burty, I furesamity: Mostry: this leost'Tre is noo's
# As y
#
# iter:4499/20000 loss:1.7362332344055176
# generated sequence: WARWICK:
# So not as whince me all thes wring.
#
# ISABELLA:
# Merefry retarie? at nothby is at is marr.
# Fir
#
# iter:4599/20000 loss:1.7074133157730103
# generated sequence: Wal some oter; Of your with
# I cuils impeicaly.
# O blight would tell mare
# Or shirges, but I ELm day hes
#
# iter:4699/20000 loss:1.707032322883606
# generated sequence: Whou, see his hance
# Of she: why wall you marremberiesing was nots main
# Dort, both rights, to ngbell y
#
# iter:4799/20000 loss:1.7225865125656128
# generated sequence: While the mank figntring!
#
# LADY S:
# Hoot there do devis to be the other our beheet
# This pre told, that
#
# iter:4899/20000 loss:1.7015336751937866
# generated sequence: Were it is no my kingle; my fathin, wethore was be.
#
# CURTIS:
# Thew, what I smilless, yet wneft the wil
#
# iter:4999/20000 loss:1.6712901592254639
# generated sequence: WARSIUS:
# Inser, with my brack if.
#
# JALILA:
# Be not goons on the mankes Koth to my or of
# Which may, sha
#
# iter:5099/20000 loss:1.6949162483215332
# generated sequence: Whey badiest to?
#
# LOWES:
# Windie poor too, I wils,
# Who which: with thy was me sim hole's generice.
#
# KI
# iter:5199/20000 loss:1.7071537971496582
# generated sequence: Wf destreaning me:
# Shembere' now the service.
#
# VELNST:
# Then slain'd holy iganings for to come.
# And ho
#
# iter:5299/20000 loss:1.6862231492996216
# generated sequence: Wallad wither, a tongue to York;
# Wher! that rach, praint is alfold by Claul solder med;
# Lorb coustch
#
# iter:5399/20000 loss:1.7111458778381348
# generated sequence: We varing there,
# Bhonoun and lie hourd's good,
# With what forwistion peccedy:
# What in muke yoy Towords
#
# iter:5499/20000 loss:1.6861637830734253
# generated sequence: Weat athy'd his lady and fear
# Meadrrenow'd ever'd, sir,
# If in thy may supp speit: demanting gan:
# a la
#
# iter:5599/20000 loss:1.66019868850708
# generated sequence: Wast, and her his to dot--
#
# Second time
# The must? IG art thy Panisepr'd,
# Good; me
# As door not: to liv
#
# iter:5699/20000 loss:1.7239387035369873
# generated sequence: Which him.
#
# GLOUCESTER:
# Alked the wein so lients all me bide's carr tage.
#
# BRUTUS:
# Nor, his give good
#
# iter:5799/20000 loss:1.713112235069275
# generated sequence: Which, our good
# Madam in quoke of canst, I selves bleaver,
# And for trick that not hert saints
# Mase by
#
# iter:5899/20000 loss:1.708778738975525
# generated sequence: With a give to it.
#
# KING RICHARD HENRY:
# Me that these more on my broy's hath though of
# you shall was,
#
# iter:5999/20000 loss:1.7074257135391235
# generated sequence: Wall that; That it 'twas conced fried, giveraty,
# Aster knowle is then I doy, loot Edwark.
#
# KING HENVY
#
# iter:6099/20000 loss:1.686853051185608
# generated sequence: Was his many of the yeven should propser, sir
# For prich thing it. Lord spirst flownon mapy,
# Ifoul the
#
# iter:6199/20000 loss:1.6977524757385254
# generated sequence: W them mantilad as myselves this heaving now be.
# O, bear of-ty a turding mady what wist.
#
# COMINIUS:
# I
#
# iter:6299/20000 loss:1.6611841917037964
# generated sequence: Whesely father should be noo;
# Who crown?
#
# CAnIOLUMIO:
# Had a distortow in back in arriettion,
# And not
#
# iter:6399/20000 loss:1.6499775648117065
# generated sequence: Why down mudderle King is things
# Whather with the crown, ando you all was your heary.
# Why them?
#
# Seco
#
# iter:6499/20000 loss:1.6931869983673096
# generated sequence: Where, by rorl is thinks by thou.
#
# HETROK:
# No comused slyap? what here, when her the Edgher,
# And meti
#
# iter:6599/20000 loss:1.6523733139038086
# generated sequence: Ward pity.
#
# CLARENCE:
# Will!
# What under land wether flow Edward you you to pake me;
# Is and Pess on my
#
# iter:6699/20000 loss:1.6867108345031738
# generated sequence: Well pray sungrosaim not, as Riverdwerm
# Will shven have fair fallain do?
#
# Sicciving.
#
# PEMEONTE:
# Them
#
# iter:6799/20000 loss:1.6790844202041626
# generated sequence: With be that it.
# ON for I wallences to he sperviones
# It when thy beftit to quarch to dettrastian?
# Whi
#
# iter:6899/20000 loss:1.6422162055969238
# generated sequence: Well well no hattrooth poor wosted
# Tlagh are so to haddey, What yat ske!
#
# KING HENRY VI:
# The pare to
#
# iter:6999/20000 loss:1.6848556995391846
# generated sequence: Which make heart soul need ailfor'd him eyen
# As will a wenced be in theege rose.
#
# VIRDUTUS IF ANTIGAN
#
# iter:7099/20000 loss:1.7001773118972778
# generated sequence: Wire no burried lord? stor our scon
# Why his upon of my hencesthing? whonk; I soons:
# Sir the sillants
#
# iter:7199/20000 loss:1.674747347831726
# generated sequence: Will What,--eres to ere.
# The it gate to Buch will, he hones the raunm head.
# If I have tell how 'em. O
#
# iter:7299/20000 loss:1.6744407415390015
# generated sequence: Wentlier Richdan,
# My soise in that us throtather forch
# And Warwis of Londer fortune
# here;
# Resen heack
#
# iter:7399/20000 loss:1.6675831079483032
# generated sequence: Well is no that fair?
#
# KING EDWARD wFISAUMIONA:
# All to more the may to talk curply honour shoes
# Shall
#
# iter:7499/20000 loss:1.6807379722595215
# generated sequence: Which is tempight of your concelivy frized;
# All not she's Jidest trues, it to-miss.
#
# AUFIDIUS:
# Pretty
#
# iter:7599/20000 loss:1.6407198905944824
# generated sequence: Wfougiend, Warwick, gots? the read;
# Prom phe unde it, it look he aw;
# And words of be you, go me's she
#
# iter:7699/20000 loss:1.634149432182312
# generated sequence: Were affort weeching and came
# Till brother.
#
# PETRUCHIO:
# This lightsher ficedune ever may not.
#
# MARCIs
#
# iter:7799/20000 loss:1.680070161819458
# generated sequence: Where for aught mistle,
# And kial what doubter.
#
# GREDIIE:
# Awlempy, sentrivow, how dowen's come weir
# Sh
#
# iter:7899/20000 loss:1.63027024269104
# generated sequence: Where you love,--whelase-percers:
# Not end deeds tearest not lais? Till voult,
# You be nock to his must
#
# iter:7999/20000 loss:1.654788851737976
# generated sequence: When tild 'em: detere to dirvercing
# his sone it which the dedy, made till go bigns.
#
# Second
# My like o
#
# iter:8099/20000 loss:1.6339915990829468
# generated sequence: Where Glase coudell spalts.
#
# Servant:
# Thee currem thy sent? thele I haw
# First not trum thate over
# Le
#
# iter:8199/20000 loss:1.627377986907959
# generated sequence: Which as your honour.
#
# HERMIONE:
# Me so stay; sorloum it grawio!
# I'll kerving shall to Come;
# Lut o'err
#
# iter:8299/20000 loss:1.6213500499725342
# generated sequence: Who ere.
# Yet yed Wording poor, that cunce:
# Wo in anmer't; by thousan hath
# Would all const no-se;
# Than
#
# iter:8399/20000 loss:1.6319825649261475
# generated sequence: Would sbalt perpetthers, my body'st gazed is muth
# And we hervo asevising leather, boy crow these blea
#
# iter:8499/20000 loss:1.6484092473983765
# generated sequence: What earty's night not not the gee.
#
# KING EDWARD Think are well: out lest hath:
# What yet us not your
#
# iter:8599/20000 loss:1.649887204170227
# generated sequence: Warm, you, and thd have you but gul ans and as littwerment.
# Leate at I'll protitind, from as
# it worad
#
# iter:8699/20000 loss:1.6254644393920898
# generated sequence: With see,? I pray,
# And repel'd spains, whent onieve saze, he was done,
# To his child: I'll enether men
#
# iter:8799/20000 loss:1.6170318126678467
# generated sequence: Ws frien.
#
# BAPTISTA:
# Is where of oo that keep yet, This, Richidetwit
# To stack, anou, sive threne agmi
#
# iter:8899/20000 loss:1.66514253616333
# generated sequence: Wat should give you to creatwild,
# And my sentings that good andinl gainsal
# me noth to be such maly th
#
# iter:8999/20000 loss:1.625404953956604
# generated sequence: Well of madman: and meafur'st me.
#
# Senveom:
# I ded, wiln strop? 'tis honesmines,
# No to druthing borcit
#
# iter:9099/20000 loss:1.6396158933639526
# generated sequence: Wathe sace ushallest confultand to gat in rehend not of
# You ance thou sufads and her:--
#
# FRIELIZEL:
# M
#
# iter:9199/20000 loss:1.6395716667175293
# generated sequence: What deat the lave
# This lay sufar would save is is hoar,
# And with led requentitispless to us now come
#
# iter:9299/20000 loss:1.6760163307189941
# generated sequence: Well all the save: therewlish.
# Lecken: you are for both meruit,
# Io, for up since: a cleas Edmas Romeo
#
# iter:9399/20000 loss:1.615659475326538
# generated sequence: WARWICKINGHEN:
# Aworn thus honour, like artuly of htrie, off you
# Therefferison is Guet moun.
#
# LEONTES:
#
# iter:9499/20000 loss:1.6580013036727905
# generated sequence: Whing did, timerby!
#
# FORD LEWARD:
# By nams; wardie teld of to not cheres:
# So duke my erpury, lice.
# Cou
#
# iter:9599/20000 loss:1.6216026544570923
# generated sequence: Wlow morsused; with nees oh!
# The but forthince with joviet
# Werl'd him for the world have meares sin,
#
# iter:9699/20000 loss:1.6301321983337402
# generated sequence: What it be'd my,
# Hath proal! aged constrembotul the bate, and cousin,
# What impetiess to by breast my
#
# iter:9799/20000 loss:1.633636474609375
# generated sequence: What it, he comish eats amo
# Asplayed; selves, not away: would alfortonour myself
# it to my fartwey the
#
# iter:9899/20000 loss:1.6241153478622437
# generated sequence: Which an aich gebs envantas him.
#
# ThiKINCTHAND:
# To a present to him!
#
# CAPULEN:
# Are well, and had in w
#
# iter:9999/20000 loss:1.6103726625442505
# generated sequence: Who, sword bine it thee.
#
# First Chare,
# Brance, thead I's, but Past from his sare and my ena;
# For hequ
#
# iter:10099/20000 loss:1.6278568506240845
# generated sequence: Which with I semond thy drallings,
# By the did for my soothar; storouny at it.
#
# ARTIO:
# Come,
# Wot that
#
# iter:10199/20000 loss:1.6393715143203735
# generated sequence: Will be no mess it
# quen froy, adving how it be a morn;
# Than it his own, to before hope, but wile; he
# iter:10299/20000 loss:1.6378488540649414
# generated sequence: What atherdolas:
# Is ventuse as not of lonb, I am as flow in joy's gob-stagy
# This be thou spees, is he
#
# iter:10399/20000 loss:1.6267616748809814
# generated sequence: Wats like of concen beingman
# For socre the bedod! Seelt the ourles, Reday that lookands we deserve,
# T
#
# iter:10499/20000 loss:1.6425352096557617
# generated sequence: Which magy you thy deat,
# And if the dur not shall death, furrhtors
# We well.
#
# LARY ANUE:
# No hold, none
#
# iter:10599/20000 loss:1.657002568244934
# generated sequence: Was shepters other fford.
# If be or my lords handle of pland but, sec Verose
# Wethincy? hath speak, and
#
# iter:10699/20000 loss:1.6465703248977661
# generated sequence: Were this wherewe some,
# No may worth me, for that formess.
# Nom think would still, do would, do soill'
#
# iter:10799/20000 loss:1.612097144126892
# generated sequence: Whack ot first
# she of his be justy touch wall art that go dusbory.
#
# BRAKENBURY:
# Ha moster's your moaf
#
# iter:10899/20000 loss:1.596278190612793
# generated sequence: Where, life, trucklen you-heen hold turn 'to brate Coriole
# And to hear alss their love!
# Hath fide wen
#
# iter:10999/20000 loss:1.6571136713027954
# generated sequence: Whith hanger things-ale, the bear the faught
# In pent then thou! are bediend minss of Frien
# thy was we
#
# iter:11099/20000 loss:1.6293896436691284
# generated sequence: WIND:
# It ruck; a watch the let, and that make dark:
# Whil, up now your vouchess with he; home,
# Geasted
#
# iter:11199/20000 loss:1.594546914100647
# generated sequence: Widant didst from your adveche.
# Well I hughles, but that.
#
# PETRUCHIO:
# If you have, for unlock your sc
#
# iter:11299/20000 loss:1.6191308498382568
# generated sequence: What in sweet word by chad fash he pray
# you had as Time o'erved well where the e'en;
# heme tay the eag
#
# iter:11399/20000 loss:1.641679286956787
# generated sequence: Which is your puil ost make is in continoth,
# And foul, my tade all they makes fool 'lobble,
# And is th
#
# iter:11499/20000 loss:1.5930932760238647
# generated sequence: WARWICK:
# O sumb wenglow pariss theyenty and rorows,
# I kning to live to Edwariss
# 'aim this more reek m
#
# iter:11599/20000 loss:1.6239230632781982
# generated sequence: Where madad, this must true;
# Frience, thee regired proich the spoling my treat.
#
# Chtriciming.
#
# Nowhof
#
# iter:11699/20000 loss:1.602949619293213
# generated sequence: We true honest out out to come:
# You who Richad sucat out to a mind,
# If prover what Lacail again your
#
# iter:11799/20000 loss:1.6143805980682373
# generated sequence: Was think your owast pitcheeds.
#
# Bitend.
#
# RICHAMD:
# Would mads to she with his their torsest were her,
#
# iter:11899/20000 loss:1.61322021484375
# generated sequence: When which yet thing lazent: from I genthdem;
# Which moint, and not life, line
# I, dain. You are to hap
#
# iter:11999/20000 loss:1.6063625812530518
# generated sequence: WARD Warwich show I bely well's the Pcabisitaily kindsly
# As counter, if thee to plays the eal,
# And kn
#
# iter:12099/20000 loss:1.6113386154174805
# generated sequence: WARET:
# Thou'st slieve ase, an beotcle of eath,
# Wings sellous disstice:
# Will fair with ftell, usured t
#
# iter:12199/20000 loss:1.6005407571792603
# generated sequence: WI FARDUKE Deward the watrend,
# Muther! your down you mejuctue you.
#
# GLOUCESTER:
# I haw, I would shall
#
# iter:12299/20000 loss:1.608975887298584
# generated sequence: What shall were poesins make bear
# To why prease an ourwabry, many let, I husband, by lay, I weak.
# Whe
#
# iter:12399/20000 loss:1.5770201683044434
# generated sequence: WI HARI I:
# Thou night
# plone; did such your gune once:
# Enjusat alongs to daint,
# For your I admentatled
#
# iter:12499/20000 loss:1.5961718559265137
# generated sequence: Whe we seat's ambend
# Then I be que I deeds
#  alingd! I first his king's nepe and fellures, suy
# Yet hat
#
# iter:12599/20000 loss:1.591611623764038
# generated sequence: Which: boy with her bust; steeking wos.
#
# ROMEO:
# Dee dewiture to Gaugt him bit mingle.
#
# Nurse:
# Yes? al
#
# iter:12699/20000 loss:1.5991461277008057
# generated sequence: Will, I grief reating.
#
# SICINIUS:
# What must that young ears: to corn, and with the heard be this deat
#
# iter:12799/20000 loss:1.6223493814468384
# generated sequence: Wheres be of ghall?
#
# Nud:
# The treation you, Out he'ld, dishinks:
# And steysek besher attert to carest
#
#
# iter:12899/20000 loss:1.608522891998291
# generated sequence: Well thy sir, if ot rive her:
# Wee, think were with a sorrow more at thy king ot the spite 'dgiate
# For
#
# iter:12999/20000 loss:1.6400970220565796
# generated sequence: WARDIUS:
# O, 't seven have tingory, we one by, marryood
# And traiftful din, shywer'd, what for this man
#
# iter:13099/20000 loss:1.6246052980422974
# generated sequence: WI Ccoss have no hald you is
# Custes on the rest's litt the galmiemforen,
# Lond your heed
# unle's is thy
#
# iter:13199/20000 loss:1.6167628765106201
# generated sequence: Why tongue, and mudse for that'sen'd.
#
# KING RICHMENENCINTIUS:
# To men.
#
# PETRUCHIO:
# What enate; bethere
#
# iter:13299/20000 loss:1.589693546295166
# generated sequence: Wisign:
# Why's tenter having secongerite and med
# you it to most shost, which so onstry, where:
# But to
#
# iter:13399/20000 loss:1.651634931564331
# generated sequence: Whou's distancoming, give hath sweet
# Eight all the can sciusing with had revards.
#
# ANTONIO:
# You shalt
#
# iter:13499/20000 loss:1.6078405380249023
# generated sequence: Was: lasd? Go.
#
# MENET:
# Gived thy highno, holy: think came as throw
# Our is my turriling add servenicio
#
# iter:13599/20000 loss:1.6163995265960693
# generated sequence: Wist!
#
# First,
# Nor purses, Sir.
#
# BUCKINGHAM:
# What that you tremptil, of foolot
# And place on I aboutwer
#
# iter:13699/20000 loss:1.61931574344635
# generated sequence: WARWICHET:
# And my lives I it iney, us to briston'n.
#
# POLIXENES:
# Fie lex them who is more consting i'
#
# iter:13799/20000 loss:1.5774229764938354
# generated sequence: Walling, 'Tis nevor.
#
# MENENIUS:
# Why, it and myself, from the have will bugepery.
#
# QUEEN MARGARET:
# O n
#
# iter:13899/20000 loss:1.5836559534072876
# generated sequence: What this if them, no me.
#
# SICINIUS:
# O drust on this brother.
#
# BISHOP:
# Filst gendin thrither, Sancted
#
# iter:13999/20000 loss:1.6174834966659546
# generated sequence: Whind durring to be in my lord.
# My frod royal brohant death, so.
#
# FRIAR LAURENT:
# What seal confend be
#
# iter:14099/20000 loss:1.644708275794983
# generated sequence: Wlows are peace to be of
# pretidion heave? and trop a' hest read sors.
#
# ThiY: shall stive Milatio.
#
# GL
#
# iter:14199/20000 loss:1.6414378881454468
# generated sequence: WISCLESS:
# I lote, Cule, to But my first:
# Dispeak to drown much exlluded.
#
# POPIO:
# A made,
# fellow your
#
# iter:14299/20000 loss:1.6371848583221436
# generated sequence: Whis, why, sheping to the Dufit be murdend
# His proceltius Moriushy, I am no joy dorish o'd-done.
#
# you
#
# iter:14399/20000 loss:1.5658972263336182
# generated sequence: WARWICK:
# Do not it of my signry: metower sit tellous.
#
# BENwOLIO:
# Gremien him, speak, gre this lance.
#
#
# iter:14499/20000 loss:1.6326037645339966
# generated sequence: Wair fare fire, wete my life.
#
# AUFIDIUS:
# The so fair them
# To hands hath nauring thooks of a
# vowour bu
#
# iter:14599/20000 loss:1.619714617729187
# generated sequence: Wair on thee, hours!
# Now Marking would you, by yen, and tohe much prassed bague,
# And with the duck to
#
# iter:14699/20000 loss:1.553861379623413
# generated sequence: Went the name and am and they tranco
# And alows, great rights?
#
# LUCIOF:
# Will, sovere such-spark: but t
#
# iter:14799/20000 loss:1.5936903953552246
# generated sequence: WGRASO:
# Have frof behallingrstak.
#
# LADY CLIO:
# My do make your pate, I have me 'thear,
# And crowning th
#
# iter:14899/20000 loss:1.5995206832885742
# generated sequence: WISTHIA:
# 'To save he be hare; I ourth you with agair's bay-shap
# Of royaltors thy good
# Come the henoth
#
# iter:14999/20000 loss:1.6085989475250244
# generated sequence: WI Lord you prace.
#
# PATEL:
# Didnome
# Some with Villo,'st this washing
# Where inself your samand for faw
#
# iter:15099/20000 loss:1.5851893424987793
# generated sequence: Will:'s thing torry!
# Art, he call a fay, my crampouth attherebit.
#
# First ISCLERRT:
# Their speak ereat
#
# iter:15199/20000 loss:1.5577298402786255
# generated sequence: Waurcle sir wors who marry on me.
#
# MIRWICAMESS:
# Made a swiet to me attin as do damand the Lord.
#
# PETR
#
# iter:15299/20000 loss:1.6033381223678589
# generated sequence: WARWUR:
# Bie of a martick! Con joy at Pens,
# Coptroager do, swake so earth, there, apperiname corrice:
# iter:15399/20000 loss:1.6024255752563477
# generated sequence: WARWICI:
# I'll be grat,
# The revenge love were lender poor
# Genttlat Marcim here's ass
# For and wish have
#
# iter:15499/20000 loss:1.5839675664901733
# generated sequence: Whence: sir.
#
# DUKE VINCENTIO:
# The mind marry, have is Trying that
# There
# The title good I do worthmen.
#
# iter:15599/20000 loss:1.6167601346969604
# generated sequence: WBignas makes fie: I, I what to do Loo', as,
# Re banding graced a half, far one than friendsliting for
#
# iter:15699/20000 loss:1.6264317035675049
# generated sequence: Weathy
# Since yerval to graves on,
# And set that monest were tood,--O, Alces;
# Orshat disserve arrow of
#
# iter:15799/20000 loss:1.5929278135299683
# generated sequence: WARLIO:
# ?e that stands, but 'tis, am a bolm old we.
#
# KING RICHARD II:
# All are-light and re nothing sk
#
# iter:15899/20000 loss:1.5670872926712036
# generated sequence: WARTHA:
# Ay, that they mount follow back, and the not: sit
# Ofking asticia's cause it worthy busiastick
#
# iter:15999/20000 loss:1.603287696838379
# generated sequence: WARWIVINCAND:
#
# GRUMIZET:
# Your cousin Rochere.
#
# KINGARET:
# From bid hate the kinds:
# Your broke we aveic
#
# iter:16099/20000 loss:1.5898756980895996
# generated sequence: WARWICt I'ld have
# As you Barth, my braidle over-our grigmes.
#
# BENVOLIO:
# And, not. Her battercath,
# Nay
#
# iter:16199/20000 loss:1.557478427886963
# generated sequence: Whill to dught Gremours,
# But I, degevor: chars my bring imposity queen be the ray, and
# For ject; thou
#
# iter:16299/20000 loss:1.586670994758606
# generated sequence: We sistician; I am than mothy
# Hear you;--the ellow, for that is suling mourdesh.
# 'Twill see you and p
#
# iter:16399/20000 loss:1.610723853111267
# generated sequence: Wizhdench about:
# A wife to furth him the spreck win thou liet-leds?
#
# ANGELO:
# But art aht a to brother
#
# iter:16499/20000 loss:1.6013710498809814
# generated sequence: WARTIANCA:
# Silavoy out and let the name hath art own.
#
# GONZOLO:
# Shall this onch of very horse, his, I
#
# iter:16599/20000 loss:1.5574560165405273
# generated sequence: Warwicy;'s goars, sistares spakes and read
# If with ableforit hath besor, of fear,
# Now go blond hole o
#
# iter:16699/20000 loss:1.608007550239563
# generated sequence: Warwick,
# By he will open and now donerdelied?
# You what weep or thioke the world,
# Thee, give verten no
#
# iter:16799/20000 loss:1.593946933746338
# generated sequence: WARWICK:
# Nomevereveage princenty her a whadst,
# And yet I plaught in the wail.
# What to mean, made them
#
# iter:16899/20000 loss:1.5743107795715332
# generated sequence: Whet is it's you
# to purding is uleve himself of know to foul!
# Ay, love unto made and the commother:
# R
#
# iter:16999/20000 loss:1.6137851476669312
# generated sequence: WA st say to us I would bear talks in protears;
# Care now thou and my twoot bugin thy purpose,
# But cal
#
# iter:17099/20000 loss:1.60164213180542
# generated sequence: Which 'Where, by in the
# childers, the tome treinand:
# Thy grand with rightage; trundisatter unlage
# Tha
#
# iter:17199/20000 loss:1.5676085948944092
# generated sequence: WING?t
# How they call thank. Is made than fees all
# Is come hard him; an hands the stabpty in or carria
#
# iter:17299/20000 loss:1.5903626680374146
# generated sequence: WIRGO:
# Well not, my wall I
# coubty sigsor'd would we weady.
#
# ANTIGONUS:
# Sir!
#
# BYCHOMBERENE:
# My parden?
#
# iter:17399/20000 loss:1.5529446601867676
# generated sequence: Whis masting or their far tell
# From thes if you have beet lersupe!
# Sublotious she this asseridire of
#
# iter:17499/20000 loss:1.587214469909668
# generated sequence: Where own, stands and it being
# Wites your pay it be lishing thrush wese, which decked withimant death
#
# iter:17599/20000 loss:1.601578712463379
# generated sequence: What he shall fon, and I'll unmer dids
# much not of stassase pawn and buftin's from our
# pistefords al
#
# iter:17699/20000 loss:1.569069504737854
# generated sequence: Well in ablond come the froth.
#
# GRUMIO:
# Shalw there being think gault it art think from the sours cou
#
# iter:17799/20000 loss:1.5658279657363892
# generated sequence: Whiren! your hard I lister,
# make niggerow:
# Inself princes at beside, slaid not to me?
# I degared this
#
# iter:17899/20000 loss:1.5668864250183105
# generated sequence: What is sho nall, your have daw your dangue:
# They is it sovereigl, think you: 'tis other
# As thy harm'
#
# iter:17999/20000 loss:1.5943870544433594
# generated sequence: WARD BOLIUS:
# Who, repelve you, one feach,
# And: the times of you, las was defend,
# I dustert of the pri
#
# iter:18099/20000 loss:1.6222572326660156
# generated sequence: Whicker as I thing.
#
# ROMEO:
# My good dailar
# And, mine record to my Puthing welmem well, when hell,
# Tho
#
# iter:18199/20000 loss:1.5817551612854004
# generated sequence: WARWIA:
# Good death he true with than this watoved wear,
# Is't I carrissen'd saints in restsle most.
#
# C
#
# iter:18299/20000 loss:1.587935209274292
# generated sequence: WARD BRIUS:
# O haste to that Eveseditumes of thee, let's wed,
# Five deferier the maid of groat of mone
#
# iter:18399/20000 loss:1.5680536031723022
# generated sequence: Which by the poor body of gloset Bain
# Stell. Away, I may awases:
# How it is MARGARET:
# Sir.
# Well, ere y
#
# iter:18499/20000 loss:1.566313624382019
# generated sequence: WGRDKERD RICHARD III:
# Duinous now; which to your kind the half here the derity.
#
# ARGHELS:
# Her for liv
#
# iter:18599/20000 loss:1.5870378017425537
# generated sequence: Where price,
# For mow three mistress.
# 's love of lie the God, hath strike,
# And request, whose sease fo
#
# iter:18699/20000 loss:1.6088310480117798
# generated sequence: Whing' down.
#
# GLOUCESTER:
# Go, as mine my dusting? To thou we shalt so, all over where.
# Mean, thenings
#
# iter:18799/20000 loss:1.595360517501831
# generated sequence: Was thy least: me? train steed, rather wind to the most a grefter.
# At, the rest wit point a weal perc
#
# iter:18899/20000 loss:1.578934669494629
# generated sequence: Wels, Good you, gange or swor;
# I muste is of to the ton, heading,
# With kind. Good quoth nirs, now,
# Wh
#
# iter:18999/20000 loss:1.5932308435440063
# generated sequence: We, sming them:
# Best shoulder we doatity a woman.
#
# GONZALO:
# Plince, doeacus, to Jucke the doward,
# Oul
#
# iter:19099/20000 loss:1.5550618171691895
# generated sequence: Warw 'Twaxing evers tare, to Lour
# poor her quift going part in time;
# Of the lams yours meins to the g
#
# iter:19199/20000 loss:1.5600204467773438
# generated sequence: Were, sir?
#
# ESCALUS:
# But, sir, o'er made sweet to shall so, have by.
#
# Servant:
# You congutes; in winde
#
# iter:19299/20000 loss:1.5871708393096924
# generated sequence: Which have these out to Rooth?
#
# LEONTES:
# Save would thenst stalian done royal.
#
# ISABELLA:
# Respeal dog
#
# iter:19399/20000 loss:1.5676789283752441
# generated sequence: WARWICHARD:
# What I to my more.
#
# FLORRI:
# Thind good in this, my lord;
# And I do help sovereigly foating
#
# iter:19499/20000 loss:1.5830491781234741
# generated sequence: Windies of himself my bary.
# But Bolin, for perpent my mostle Mastore,
# They quarur, on you shall not b
#
# iter:19599/20000 loss:1.5710265636444092
# generated sequence: Which he away our soldiers.
#
# RICHARD:
# I perfor man, this?
#
# QUEEN ELIZEL:
# What he sollution you,
# Be pu
#
# iter:19699/20000 loss:1.5895142555236816
# generated sequence: WARKIUS:
# Fie dands.
#
# KATHARINA:
# I drieks with the doth womis, ate,--
#
# MENENIUS:
# Who dis lovis that he
#
# iter:19799/20000 loss:1.613472580909729
# generated sequence: Warwick too flong-deen
# morn, then treesting is of the deathed
# Well son will erteanning to the save
# An
#
# iter:19899/20000 loss:1.582377314567566
# generated sequence: Wlike all to killing.
#
# Servanty:
# Lould the weok love to a brother the greats your and monure thy exta
#
# iter:19999/20000 loss:1.5819035768508911
# generated sequence: Were ever leavise there, that his cause,
# For the preatures and she lent 'twis dewing
# The infusquer I

# %% [markdown]
# #### Training Loss Curve

# %%
plt.xlabel('iters')
plt.ylabel('loss')
plt.plot(all_losses)
plt.show()

# %% [markdown]
# #### Evaluation: A Sample of Generated Sequence

# %%
print(eval_step(net, predicted_len=600))
